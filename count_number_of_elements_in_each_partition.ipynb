# %%
df1 = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/billcates.m@lntinfotech.com/pageview-1.csv")

# %%
display(df1.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Site</th><th>www.learntospark.com</th></tr></thead><tbody><tr><td>Desccription</td><td>Complete guide to learn Spark,AI,ML</td></tr><tr><td>Page Views of each blog</td><td>null</td></tr><tr><td>20200817-20200817</td><td>null</td></tr><tr><td>Total data in page</td><td>12</td></tr><tr><td>Page</td><td>Date</td></tr></tbody></table></div>

# %%
spark.conf.set("spark.sql.shuffle.partitions","10")

# %%
from pyspark.sql.functions import spark_partition_id

# %%
df1=df1.repartition(4)

# %%
df2=df1.withColumn("partition_id",spark_partition_id())

# %%
df2.groupBy("partition_id").count().show()
# Out:
# +------------+-----+
# |partition_id|count|
# +------------+-----+
# |           0|    5|
# |           1|    5|
# |           2|    5|
# |           3|    5|
# +------------+-----+
