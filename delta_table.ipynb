# %%
df = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/billcates.m@lntinfotech.com/circuits.csv")

# %%
display(df.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.write.format("delta").save("/user/practice/circuits")

# %%
# %sql
create table circuits
using delta
location '/user/practice/circuits'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# print the history

# %%
from delta.tables import DeltaTable
# Open the Delta table
delta_table = DeltaTable.forPath(spark, "/user/practice/circuits")

# Get the commit history as a DataFrame
history_df = delta_table.history()

# Display the commit history

# %%
display(history_df.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.write.format("delta").mode("overwrite").save("/user/practice/circuits")

# %%
delta_table = DeltaTable.forPath(spark, "/user/practice/circuits")

# Get the commit history as a DataFrame
history_df = delta_table.history()

# Display the commit history
display(history_df.limit(4))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df1=spark.read.format("delta").option("versionAsOf", 0).load("/user/practice/circuits")

# %%
display(df1.limit(4))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# Vaccum command is used to delete the older versioned files which are not pointed as the current version
